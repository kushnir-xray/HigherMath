# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def polar_circle(R=1):
    fi = np.linspace(0, 2 * np.pi, 101)
    r = np.linspace(R, R, 101)
    plt.polar(fi, r, color='red')
    plt.show()
polar_circle()
