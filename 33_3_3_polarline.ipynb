# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def polar_line(R=1, a=90):
    fi = np.array([np.radians(a), np.radians(a)])
    r = np.array([0, R])
    plt.polar(fi, r)
    plt.show()
polar_line(R=7, a=60)
